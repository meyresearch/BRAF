# %%
import pandas as pd
import xml.etree.ElementTree as ET
import os
from urllib.request import urlretrieve as download
from glob import glob as g
from Bio.Blast import NCBIWWW, NCBIXML
from mypdb import PDB_file as mypdb
from Bio.Blast.Applications import NcbipsiblastCommandline
from time import time as t
from tqdm.notebook import tqdm


import glob
from collections import defaultdict

import re
import MDAnalysis as mda

# %% [markdown]
# ### Get PDBs general information from the InterPro tsv file: `structure-matching-IPR011009.tsv`

# %%
structure_path = 'structure-matching-IPR011009.tsv'
pdb_data = pd.read_csv(structure_path, sep = "\t", header=0, engine='python')
pdb_data['Accession'] = pdb_data['Accession'].str.upper()

# %% [markdown]
# ## Download PDBs

# %%
"""
We use a multi-thread program to download PDBs. According to the problems encountered, each failure will retry 3 times.
There should be no empty .pdb files in ./PDBs (i.e. files that are 0 KB)
It takes about 13 minutes for my device to complete the download. I think within 30 minutes could be a normal time. 
"""

import os
import requests
import time
import concurrent.futures
import multiprocessing

def download2(code, pdir=None, max_retries=3):
    """Download a PDB file with retry mechanism and failure handling"""
    base_url = "https://files.rcsb.org/download"
    pdb_url = f"{base_url}/{code}.pdb"
    f_p = os.path.join(pdir, f"{code}.pdb")

    for attempt in range(max_retries):
        try:
            response = requests.get(pdb_url, stream=True, timeout=10)
            if response.status_code == 404:
                print(f"{code} does not exist (404 Not Found)")
                return None
            response.raise_for_status()
            
            with open(f_p, "wb") as f:
                for chunk in response.iter_content(chunk_size=8192):
                    f.write(chunk)

            # Check file size to prevent empty files
            if os.path.getsize(f_p) == 0:
                print(f"{code}.pdb download failed (empty file), retrying {attempt+1}/{max_retries}...")
                os.remove(f_p)
                continue  # Retry

            print(f"{code}.pdb downloaded successfully")
            return f_p
        except requests.exceptions.RequestException as e:
            print(f"{code}.pdb download failed, retrying {attempt+1}/{max_retries}... Error: {e}")
            time.sleep(2)

    print(f"{code}.pdb download ultimately failed")
    return None


def download_pdbs(pdb_list, pdir=None):
    """Download multiple PDB files"""
    default_dir = "./PDBs"
    pdir = os.path.abspath(pdir if pdir else default_dir)
    os.makedirs(pdir, exist_ok=True)

    # Get already downloaded PDB files to avoid duplicate downloads
    existing_files = {os.path.splitext(f)[0] for f in os.listdir(pdir)}

    for code in pdb_list:
        if code not in existing_files:
            file_path = download2(code, pdir=pdir)
            if file_path:
                print(f"{code} downloaded successfully")
            else:
                print(f"{code} download failed")


def parallel_download(pdb_list, pdir=None):
    """Download PDB files in parallel"""
    num_workers = min(20, multiprocessing.cpu_count()*2)  # Limit the number of threads
    chunk_size = max(10, len(pdb_list) // num_workers)  # Each thread handles at least 10 PDB files

    splited_pdb_lists = [pdb_list[i:i+chunk_size] for i in range(0, len(pdb_list), chunk_size)]

    with concurrent.futures.ThreadPoolExecutor(max_workers=num_workers) as executor:
        executor.map(download_pdbs, splited_pdb_lists)

# %%
pdbs_ids = pdb_data['Accession'].tolist()
parallel_download(pdbs_ids)
# Out:
# 7BL1 does not exist (404 Not Found)
# 7BL1 download failed
# 7OZB does not exist (404 Not Found)
# 7OZB download failed
# 6TLU does not exist (404 Not Found)
# 6TLU download failed
# 6Q38 does not exist (404 Not Found)
# 6Q38 download failed
# 8ATL does not exist (404 Not Found)
# 8ATL download failed
# 8PYI does not exist (404 Not Found)
# 8PYI download failed
# 9INW does not exist (404 Not Found)
# 9INW download failed
# 6BCU does not exist (404 Not Found)
# 6BCU download failed
# 7OZD does not exist (404 Not Found)
# 7OZD download failed
# 8ATN does not exist (404 Not Found)
# 8ATN download failed
# 7EGB does not exist (404 Not Found)
# 7EGB download failed
# 8PYJ does not exist (404 Not Found)
# 8PYJ download failed
# 6YKG does not exist (404 Not Found)
# 6YKG download failed
# 9INX does not exist (404 Not Found)
# 9INX download failed
# 6BCX does not exist (404 Not Found)
# 6BCX download failed
# 6Q4Q does not exist (404 Not Found)
# 6Q4Q download failed
# 7OZF does not exist (404 Not Found)
# 7OZF download failed
# 8BH3 does not exist (404 Not Found)
# 8BH3 download failed
# 8PYK does not exist (404 Not Found)
# 8PYK download failed
# 7EGC does not exist (404 Not Found)
# 7EGC download failed
# 6YUL does not exist (404 Not Found)
# 6YUL download failed
# 6QX9 does not exist (404 Not Found)
# 6QX9 download failed
# 8BHV does not exist (404 Not Found)
# 8BHV download failed
# 8PYL does not exist (404 Not Found)
# 8PYL download failed
# 7OZY does not exist (404 Not Found)
# 7OZY download failed
# 7ENA does not exist (404 Not Found)
# 7ENA download failed
# 6YUM does not exist (404 Not Found)
# 6YUM download failed
# 6T28 does not exist (404 Not Found)
# 6T28 download failed
# 8PYM does not exist (404 Not Found)
# 8PYM download failed
# 8BHY does not exist (404 Not Found)
# 8BHY download failed
# 7P5Z does not exist (404 Not Found)
# 7P5Z download failed
# 7ENC does not exist (404 Not Found)
# 7ENC download failed
# 6T29 does not exist (404 Not Found)
# 6Z1Q does not exist (404 Not Found)
# 6Z1Q download failed
# 6T29 download failed
# 8PYN does not exist (404 Not Found)
# 8PYN download failed
# 7PI4 does not exist (404 Not Found)
# 7PI4 download failed
# 8BOT does not exist (404 Not Found)
# 8BOT download failed
# 7KTS does not exist (404 Not Found)
# 7KTS download failed
# 6Z1T does not exist (404 Not Found)
# 6Z1T download failed
# 8QXD does not exist (404 Not Found)
# 8QXD download failed
# 7PQH does not exist (404 Not Found)
# 7PQH download failed
# 7LBM does not exist (404 Not Found)
# 7LBM download failed
# 8BR5 does not exist (404 Not Found)
# 8BR5 download failed
# 6Z83 does not exist (404 Not Found)
# 6Z83 download failed
# 8R08 does not exist (404 Not Found)
# 8R08 download failed
# 7PT6 does not exist (404 Not Found)
# 7PT6 download failed
# 7MF0 does not exist (404 Not Found)
# 7MF0 download failed
# 8BR6 does not exist (404 Not Found)
# 8BR6 download failed
# 6Z84 does not exist (404 Not Found)
# 6Z84 download failed
# 8R0A does not exist (404 Not Found)
# 8R0A download failed
# 7PT7 does not exist (404 Not Found)
# 7PT7 download failed
# 7MU6 does not exist (404 Not Found)
# 7MU6 download failed
# 8BR7 does not exist (404 Not Found)
# 8BR7 download failed
# 7PUS does not exist (404 Not Found)
# 7PUS download failed
# 7NB1 does not exist (404 Not Found)
# 8RPC does not exist (404 Not Found)
# 8RPC download failed
# 7NB1 download failed
# 8BVW does not exist (404 Not Found)
# 8BVW download failed
# 7Q52 does not exist (404 Not Found)
# 7Q52 download failed
# 8RRQ does not exist (404 Not Found)
# 8RRQ download failed
# 7NB2 does not exist (404 Not Found)
# 7NB2 download failed
# 8BYQ does not exist (404 Not Found)
# 8BYQ download failed
# 7Q6H does not exist (404 Not Found)
# 7Q6H download failed
# 8RRZ does not exist (404 Not Found)
# 8RRZ download failed
# 8C12 does not exist (404 Not Found)
# 8C12 download failed
# 7NB3 does not exist (404 Not Found)
# 7NB3 download failed
# 7QHW does not exist (404 Not Found)
# 7QHW download failed
# 8RXR does not exist (404 Not Found)
# 8RXR download failed
# 8CBJ does not exist (404 Not Found)
# 8CBJ download failed
# 7OA0 does not exist (404 Not Found)
# 7OA0 download failed
# 7UXH does not exist (404 Not Found)
# 7UXH download failed
# 8EJ4 does not exist (404 Not Found)
# 8EJ4 download failed
# 8S3R does not exist (404 Not Found)
# 8S3R download failed
# 7V3V does not exist (404 Not Found)
# 7V3V download failed
# 8S3X does not exist (404 Not Found)
# 8S3X download failed
# 8EQ9 does not exist (404 Not Found)
# 8EQ9 download failed
# 7Z37 does not exist (404 Not Found)
# 7Z37 download failed
# 8S85 does not exist (404 Not Found)
# 8S85 download failed
# 8EQD does not exist (404 Not Found)
# 8EQD download failed
# 7Z6I does not exist (404 Not Found)
# 7Z6I download failed
# 8EQE does not exist (404 Not Found)
# 8EQE download failed
# 8VF6 does not exist (404 Not Found)
# 8VF6 download failed
# 7Z9T does not exist (404 Not Found)
# 7Z9T download failed
# 8GXQ does not exist (404 Not Found)
# 8GXQ download failed
# 8VOF does not exist (404 Not Found)
# 8VOF download failed
# 8VQ3 does not exist (404 Not Found)
# 8VQ3 download failed
# 8ACM does not exist (404 Not Found)
# 8ACM download failed
# 8GXS does not exist (404 Not Found)
# 8GXS download failed
# 8VQ4 does not exist (404 Not Found)
# 8VQ4 download failed
# 8ACO does not exist (404 Not Found)
# 8ACO download failed
# 8H6E does not exist (404 Not Found)
# 8H6E download failed
# 8ATB does not exist (404 Not Found)
# 8ATB download failed
# 8VXD does not exist (404 Not Found)
# 8VXD download failed
# 8H6J does not exist (404 Not Found)
# 8H6J download failed
# 8VXE does not exist (404 Not Found)
# 8VXE download failed
# 8IYJ does not exist (404 Not Found)
# 8IYJ download failed
# 8VXF does not exist (404 Not Found)
# 8VXF download failed
# 8OTZ does not exist (404 Not Found)
# 8OTZ download failed
# 8W1L does not exist (404 Not Found)
# 8W1L download failed
# 8W3W does not exist (404 Not Found)
# 8W3W download failed
# 8W3X does not exist (404 Not Found)
# 8W3X download failed
# 8XFM does not exist (404 Not Found)
# 8XFM download failed
# 8XFY does not exist (404 Not Found)
# 8XFY download failed
# 8XLO does not exist (404 Not Found)
# 8XLO download failed
# 8XLQ does not exist (404 Not Found)
# 8XLQ download failed
# 8XN7 does not exist (404 Not Found)
# 8XN7 download failed
# 8XVG does not exist (404 Not Found)
# 8XVG download failed
# 8XZ7 does not exist (404 Not Found)
# 8XZ7 download failed
# 8Y22 does not exist (404 Not Found)
# 8Y22 download failed
# 8Y6O does not exist (404 Not Found)
# 8Y6O download failed
# 8YHF does not exist (404 Not Found)
# 8YHF download failed
# 8YHL does not exist (404 Not Found)
# 8YHL download failed
# 8YKI does not exist (404 Not Found)
# 8YKI download failed
# 8ZTX does not exist (404 Not Found)
# 8ZTX download failed
# 8ZU2 does not exist (404 Not Found)
# 8ZU2 download failed
# 8ZUD does not exist (404 Not Found)
# 8ZUD download failed
# 8ZUL does not exist (404 Not Found)
# 8ZUL download failed
# 9AXA does not exist (404 Not Found)
# 9AXA download failed
# 9AXC does not exist (404 Not Found)
# 9AXC download failed
# 9AXH does not exist (404 Not Found)
# 9AXH download failed
# 9AXM does not exist (404 Not Found)
# 9AXM download failed
# 9AXX does not exist (404 Not Found)
# 9AXX download failed
# 9AXY does not exist (404 Not Found)
# 9AXY download failed
# 9AY7 does not exist (404 Not Found)
# 9AY7 download failed
# 9AYA does not exist (404 Not Found)
# 9AYA download failed
# 9BFB does not exist (404 Not Found)
# 9BFB download failed
# 9BHI does not exist (404 Not Found)
# 9BHI download failed
# 9BHJ does not exist (404 Not Found)
# 9BHJ download failed
# 9BHK does not exist (404 Not Found)
# 9BHK download failed
# 9BI8 does not exist (404 Not Found)
# 9BI8 download failed
# 9BIK does not exist (404 Not Found)
# 9BIK download failed
# 9BJ1 does not exist (404 Not Found)
# 9BJ1 download failed
# 9C1R does not exist (404 Not Found)
# 9C1R download failed
# 9C82 does not exist (404 Not Found)
# 9C82 download failed
# 9CD5 does not exist (404 Not Found)
# 9CD5 download failed
# 9CD7 does not exist (404 Not Found)
# 9CD7 download failed
# 9CE4 does not exist (404 Not Found)
# 9CE4 download failed
# 9CJ3 does not exist (404 Not Found)
# 9CJ3 download failed
# 9CJ5 does not exist (404 Not Found)
# 9CJ5 download failed
# 9CMZ does not exist (404 Not Found)
# 9CMZ download failed
# 9D8E does not exist (404 Not Found)
# 9D8E download failed
# 9D8F does not exist (404 Not Found)
# 9D8F download failed
# 9D8Z does not exist (404 Not Found)
# 9D8Z download failed
# 9DUB does not exist (404 Not Found)
# 9DUB download failed
# 9DUE does not exist (404 Not Found)
# 9DUE download failed
# 9EP8 does not exist (404 Not Found)
# 9EP8 download failed
# 9EPV does not exist (404 Not Found)
# 9EPV download failed
# 9EPW does not exist (404 Not Found)
# 9EPW download failed
# 9EPX does not exist (404 Not Found)
# 9EPX download failed
# 9EPY does not exist (404 Not Found)
# 9EPY download failed
# 9EPZ does not exist (404 Not Found)
# 9EPZ download failed
# 9EQ0 does not exist (404 Not Found)
# 9EQ0 download failed
# 9EQ1 does not exist (404 Not Found)
# 9EQ1 download failed
# 9ESA does not exist (404 Not Found)
# 9ESA download failed
# 9EWS does not exist (404 Not Found)
# 9EWS download failed
# 9EWT does not exist (404 Not Found)
# 9EWT download failed
# 9EZ3 does not exist (404 Not Found)
# 9EZ3 download failed
# 9EZG does not exist (404 Not Found)
# 9EZG download failed
# 9F3V does not exist (404 Not Found)
# 9F3V download failed
# 9FLB does not exist (404 Not Found)
# 9FLB download failed
# 9FLC does not exist (404 Not Found)
# 9FLC download failed
# 9FLO does not exist (404 Not Found)
# 9FLO download failed
# 9FLQ does not exist (404 Not Found)
# 9FLQ download failed
# 9FLR does not exist (404 Not Found)
# 9FLR download failed
# 9FLT does not exist (404 Not Found)
# 9FLT download failed
# 9FPD does not exist (404 Not Found)
# 9FPD download failed
# 9FR2 does not exist (404 Not Found)
# 9FR2 download failed
# 9FYF does not exist (404 Not Found)
# 9FYF download failed
# 9GBE does not exist (404 Not Found)
# 9GBE download failed
# 9H46 does not exist (404 Not Found)
# 9H46 download failed

# %% [markdown]
# ### Count download results

# %%
import os
import pandas as pd

folder_path = ".\PDBs"
file_names = [os.path.splitext(f)[0] for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]
pdb_raw = pd.DataFrame({"PDBs": file_names})

pdb_data['Downloaded'] = pdb_data['Accession'].str.upper().isin(pdb_raw['PDBs']).map({True: True, False: False})

counts = pdb_data['Downloaded'].value_counts().to_dict()
print(f"Downloaded: {counts[True]}, Failed: {counts[False]}")
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\P'
# <>:4: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\Oakclimber\AppData\Local\Temp\ipykernel_4804\4093886425.py:4: SyntaxWarning: invalid escape sequence '\P'
#   folder_path = ".\PDBs"
# Downloaded: 8054, Failed: 169

# %% [markdown]
# ### Save failure downloads to `fail_list.csv`

# %%
fail_list = pdb_data[pdb_data['Downloaded']==False]
fail_list.to_csv('fail_list.csv')

# %% [markdown]
# ## Stripping the downloaded PDBs to chains of interests.

# %%
""" 
Use multiprocessing to accelerate stripping process.
The main code is in `strip_pdb.py`
"""
import sys
import subprocess

# Use the current python environment 
python_executable = sys.executable

cmd = [python_executable, "strip_pdb.py"]
result = subprocess.run(cmd, capture_output=True, text=True)

# Output prints
print(result.stdout)
print(result.stderr)
